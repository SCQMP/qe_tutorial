# %%
# %%
import numpy as np
import matplotlib.pyplot as plt
from qwt.qe import read_band_structure

kpath, kpoints, enk = read_band_structure("./bands/graphene.xml")
ymin, ymax = -3, 3 # eV

nkl = 30
nnkl = 4
kticks = kpath[nkl*np.arange(nnkl)]
klabels = ['$\Gamma$', '$K$', '$M$', '$\Gamma$']
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\G'
# <>:12: SyntaxWarning: invalid escape sequence '\G'
# <>:12: SyntaxWarning: invalid escape sequence '\G'
# <>:12: SyntaxWarning: invalid escape sequence '\G'
# /tmp/ipykernel_2337900/2408161309.py:12: SyntaxWarning: invalid escape sequence '\G'
#   klabels = ['$\Gamma$', '$K$', '$M$', '$\Gamma$']
# /tmp/ipykernel_2337900/2408161309.py:12: SyntaxWarning: invalid escape sequence '\G'
#   klabels = ['$\Gamma$', '$K$', '$M$', '$\Gamma$']

# %%
plt.figure(figsize=(2,2),dpi=300,layout='constrained')
plt.axhline(0, color='lightgray', linestyle='--', lw=0.5)
plt.grid(axis='x', color='lightgray', linestyle='--', lw=0.5)
for ib in range(enk.shape[1]):
    plt.plot(kpath, enk[:, ib], "k-")
plt.xticks(kticks, klabels)
plt.xlim(kpath[0], kpath[-1])
plt.ylim(ymin, ymax)
plt.ylabel("Energy (eV)")
plt.savefig("bands.png")

# %%
